# %%
import pandas as pd

# %%
before = pd.read_csv("../dataset/layer1.csv")
before.head()
# Out:
#            id                               title partition  \
# 0  000018c8a5          Worlds Best Mac and Cheese     train
# 1  000033e39b         Dilly Macaroni Salad Recipe     train
# 2  000035f7ed                            Gazpacho     train
# 3  00003a70b1           Crunchy Onion Potato Bake      test
# 4  00004320bb  Cool 'n Easy Creamy Watermelon Pie     train
#
#                                                  url  \
# 0  http://www.epicurious.com/recipes/food/views/-...
# 1  http://cookeatshare.com/recipes/dilly-macaroni...
# 2  http://www.foodnetwork.com/recipes/gazpacho1.html
# 3  http://www.food.com/recipe/crunchy-onion-potat...
# 4  http://www.food.com/recipe/cool-n-easy-creamy-...
#
#                                         instructions  \
# 0  Preheat the oven to 350 F. Butter or oil an 8-...
# 1  Cook macaroni according to package directions;...
# 2  Add the tomatoes to a food processor with a pi...
# 3  Preheat oven to 350 degrees Fahrenheit.;Spray ...
# ...

# %%
after = pd.read_csv("../dataset/dataset_merged/train_merged.csv")
after.head()
# Out:
#            id                               title partition  \
# 0  00007bfd16        Strawberry Rhubarb Dump Cake     train
# 1  00010379bf       Brown Sugar 'Karintou' Snacks     train
# 2  00010c7867      Grandmommy's Mexicali Meatloaf     train
# 3  00010d44c7                  Broccoli Rice Bake     train
# 4  000238353f  Sausage and marmalade plait recipe     train
#
#                                                  url  \
# 0  http://www.food.com/recipe/strawberry-rhubarb-...
# 1  https://cookpad.com/us/recipes/156014-brown-su...
# 2  http://www.food.com/recipe/grandmommys-mexical...
# 3  http://www.food.com/recipe/broccoli-rice-bake-...
# 4  http://www.lovefood.com/guide/recipes/27146/sa...
#
#                                         instructions  \
# 0  put ingredient buttered 9 x 12 x 2 inch pan ev...
# 1  bowl mix flour baking powder sugar add sesame ...
# 2  combine beef oat tomato juice egg 1 tsp salt p...
# 3  mix ingredient pour one quart baking dish;bake...
# ...

# %%
before.loc[before["id"] == "00010d44c7"].to_html("before.html")

# %%
after.loc[after["id"] == "00010d44c7"].to_html("after.html")
# Out:
# [['00010d44c7' 'Broccoli Rice Bake' 'train'
#   'http://www.food.com/recipe/broccoli-rice-bake-30406'
#   'mix ingredient pour one quart baking dish;bake 350 20 minute;top remaining 1 2 cup cheese continue baking 10 minute'
#   '9f497dcfa5.jpg' 'broccoli;eggs;butter;milk;onion;garlic;pepper']]
